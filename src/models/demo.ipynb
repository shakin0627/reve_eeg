# %%
! torchrun --nproc_per_node=gpu src/dt_norm.py \
  --config-name config_dt_norm.yaml \
  task=faced \
  data_root=data \
  pretrained_path=hf:brain-bzh/reve-base \
  training_mode=ft
# Out:
# Running cells with '.venv (3.13.12) (Python 3.13.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/shakin/project/pmpp/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
